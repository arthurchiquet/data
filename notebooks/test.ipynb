# %%
pip install turfpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 MB 7.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.14.1 which is incompatible.
# ...

# %%
import requests

url = "https://raw.githubusercontent.com/arthurchiquet/data/refs/heads/main/communes_aoc.geojson"

response = requests.get(url)
communes = response.json()

# %%
from turfpy.transformation import intersect
master_key = '$2a$10$Mt.bSK/NasScMiJn7jM6suAhNBeB2diH2t35jshtH3g3djjmZRNNO'
jsonbin_url = 'https://api.jsonbin.io/v3/b'

# %%
i = 1
from geojson import FeatureCollection
import json
import random
import string
length = 10

for feature in communes['features']:
    print(f"commune {i}/300")
    url = f"https://cadastre.data.gouv.fr/bundler/cadastre-etalab/communes/{feature['properties']['code']}/geojson/lieux_dits"
    response = requests.get(url)
    lds = response.json()
    intersection = []
    try:
      for f in lds['features']:
          it = intersect([f, feature["geometry"]])
          it['id'] = random.randint(1, 10000000)
          try:
            if it["geometry"]["coordinates"]!= [[]]:
              intersection.append(it)
          except:
            print(f)
    except:
      print(feature['properties']['code'])
    with open(f"lieux_dits/{feature['properties']['code']}.geojson", 'w') as json_file:
      json.dump(FeatureCollection(intersection), json_file)
    i+=1
# Out:
# commune 1/300
# commune 2/300
# commune 3/300
# commune 4/300
# commune 5/300
# commune 6/300
# commune 7/300
# commune 8/300
# commune 9/300
# commune 10/300
# commune 11/300
# commune 12/300
# commune 13/300
# commune 14/300
# commune 15/300
# commune 16/300
# commune 17/300
# commune 18/300
# commune 19/300
# commune 20/300
# commune 21/300
# commune 22/300
# commune 23/300
# commune 24/300
# commune 25/300
# commune 26/300
# commune 27/300
# commune 28/300
# commune 29/300
# commune 30/300
# commune 31/300
# commune 32/300
# commune 33/300
# commune 34/300
# commune 35/300
# 51637
# commune 36/300
# commune 37/300
# commune 38/300
# commune 39/300
# commune 40/300
# commune 41/300
# commune 42/300
# commune 43/300
# commune 44/300
# commune 45/300
# commune 46/300
# commune 47/300
# commune 48/300
# commune 49/300
# commune 50/300
# commune 51/300
# commune 52/300
# commune 53/300
# commune 54/300
# commune 55/300
# commune 56/300
# commune 57/300
# commune 58/300
# ...

# %%
import shutil
from google.colab import files

# Spécifiez le chemin du dossier à compresser
folder_path = 'lieux_dits'  # Remplacez par le chemin de votre dossier

# Créer une archive ZIP du dossier
shutil.make_archive('lieux_dits', 'zip', folder_path)

# Télécharger l'archive ZIP
# Out:
# '/content/lieux_dits.zip'
